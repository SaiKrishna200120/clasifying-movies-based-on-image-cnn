# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
# mkdir: cannot create directory ‘/tmp/Multimodal_IMDB_dataset’: File exists
#               0   0%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/7897)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):

  image = tf.image.convert_image_dtype(image, dtype = tf.float32)

  # resizing image
  image = tf.image.resize(image, [64,64])

  return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

# Batch size
batch_size = 64

# Parse and process the training dataset with batch vectorization
posters_train_ds = (
    list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse images
    .batch(batch_size)  # Batch the dataset
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Process the batch
    .cache()  # Cache for performance
    .shuffle(buffer_size=1000)  # Shuffle for randomness
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# Parse and process the validation dataset with batch vectorization
posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse images
    .batch(batch_size)  # Batch the dataset
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Process the batch
    .cache()  # Cache for performance
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

# Batch size
batch_size = 64

# Placeholder for preprocessing function (e.g., tokenization)
def process_text(text, label):
    # Convert text to lower case, strip whitespace, or apply tokenization
    text = tf.strings.lower(text)
    text = tf.strings.strip(text)
    return text, label

# Training dataset
overviews_train_ds = (
    list_overviews_train_ds
    .map(process_text, num_parallel_calls=tf.data.AUTOTUNE)  # Process text
    .batch(batch_size)  # Batch the dataset
    .cache()  # Cache for performance
    .shuffle(buffer_size=1000)  # Shuffle for randomness
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# Validation dataset
overviews_valid_ds = (
    list_overviews_valid_ds
    .map(process_text, num_parallel_calls=tf.data.AUTOTUNE)  # Process text
    .batch(batch_size)  # Batch the dataset
    .cache()  # Cache for performance
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

# Constants
VOCAB_SIZE = 10000  # Set the desired vocabulary size
SEQUENCE_LENGTH = 100  # Define a fixed sequence length
BATCH_SIZE = 64  # Batch size for loading data

# Define the TextVectorization layer with output_sequence_length
encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE,  # Limit the size of the vocabulary
    output_mode='int',  # Convert tokens to integers
    output_sequence_length=SEQUENCE_LENGTH  # Pad/truncate to a fixed length
)

# Process the training dataset: map the overview (text) and label separately
overviews_train_ds_processed = (
    list_overviews_train_ds
    .map(lambda overview, label: overview)  # Extract only the overview text
    .batch(BATCH_SIZE)  # Apply batching first
)

# Adapt the encoder to the training dataset
encoder.adapt(overviews_train_ds_processed)

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

vocabulary = encoder.get_vocabulary()

# Print the first 200 words (tokens) of the vocabulary
print(vocabulary[:200])
# Out:
# ['', '[UNK]', 'a', 'the', 'to', 'of', 'and', 'in', 'his', 'is', 'an', 'with', 'her', 'for', 'on', 'he', 'their', 'who', 'by', 'when', 'from', 'as', 'that', 'after', 'young', 'life', 'they', 'man', 'at', 'him', 'two', 'new', 'are', 'but', 'into', 'has', 'she', 'up', 'woman', 'love', 'family', 'one', 'out', 'find', 'must', 'friends', 'be', 'world', 'story', 'finds', 'it', 'school', 'them', 'where', 'about', 'while', 'group', 'years', 'girl', 'have', 'father', 'town', 'lives', 'wife', 'three', 'home', 'help', 'city', 'all', 'get', 'war', 'becomes', 'during', 'back', 'son', 'boy', 'only', 'which', 'between', 'himself', 'time', 'york', 'gets', 'high', 'against', 'american', 'tries', 'police', 'other', 'murder', 'mother', 'former', 'falls', 'takes', 'own', 'daughter', 'before', 'friend', 'team', 'small', 'its', 'down', 'order', 'being', 'will', 'become', 'can', 'death', 'old', 'was', 'save', 'college', 'agent', 'way', 'this', 'together', 'take', 'through', 'people', 'not', 'over', 'goes', 'set', 'more', 'meets', 'go', 'brother', 'returns', 'off', 'relationship', 'couple', 'hes', 'mysterious', 'killer', 'husband', 'each', 'day', 'now', 'discovers', 'best', 'what', 'secret', 'job', 'first', 'make', 'been', 'stop', 'work', 'forced', 'begins', 'living', 'us', 'past', 'comes', 'cop', 'men', 'just', 'house', 'married', 'four', 'drug', 'local', 'evil', 'turns', 'whose', 'student', 'parents', 'trying', 'teenage', 'sent', 'film', 'discover', 'detective', 'than', 'or', 'live', 'try', 'earth', 'soon', 'prison', 'fight', 'black', 'movie', 'most', 'come', 'series', 'brothers', 'another', 'there', 'some', 'women', 'so', 'crime', 'true', 'trip', 'money', 'last', 'killed', 'herself', 'away']

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    # Input layer
    inputs = Input(shape=(64, 64, 3), name="Input")

    # Conv0 and Drop1
    x = Conv2D(filters=16, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu", name="Conv0")(inputs)
    x = Dropout(rate=0.2, name="Drop1")(x)

    # Conv1, Conv2, Drop2, and Pool1
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(x)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(x)
    x = Dropout(rate=0.2, name="Drop2")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool1")(x)

    # Conv3, Conv4, Drop3, and Pool2
    x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
    x = Dropout(rate=0.2, name="Drop3")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool2")(x)

    # Conv5, Conv6, Drop4, and Pool3
    x = Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(x)
    x = Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
    x = Dropout(rate=0.2, name="Drop4")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool3")(x)

    # Flatten Layer
    x = Flatten(name="Flat")(x)

    # Fully Connected Layers with Dropout
    x = Dense(units=1024, activation="relu", name="FC1")(x)
    x = Dropout(rate=0.5, name="Drop5")(x)
    x = Dense(units=1024, activation="relu", name="FC2")(x)
    x = Dropout(rate=0.5, name="Drop6")(x)

    # Output Layer
    outputs = Dense(units=25, activation="sigmoid", name="Output")(x)

    # Create Model
    model = Model(inputs=inputs, outputs=outputs, name="model")

    return model

# Build and summarize the model
cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

cnn_model.summary()
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=Adam(learning_rate=1e-4),  # Adam optimizer with learning rate 1e-4
    loss="binary_crossentropy",         # Binary crossentropy loss
    metrics=[Precision(name="precision"), Recall(name="recall")]  # Precision and Recall as metrics
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

vocab_size = len(encoder.get_vocabulary())
# Create a Sequential model and add the embedding layer
embedder = Sequential([
    Embedding(
        input_dim=vocab_size,  # Length of the vocabulary
        output_dim=256,        # Output dimensions
        mask_zero=True,        # Mask padding tokens (index 0)
        name="Embedding"
    )
])

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = keras.Sequential([
    encoder,
    embedder,
    keras.layers.Bidirectional(keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)),
    keras.layers.Bidirectional(keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.8),
    keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization_1                 │ (None, 100)                 │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_12 (Sequential)           │ (None, 100, 256)            │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 100, 512)            │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_3 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

# Compile the model
lstm_model.compile(
    loss="binary_crossentropy",  # Loss function for multi-label classification
    optimizer=Adam(learning_rate=1e-4),  # Adam optimizer with learning rate of 1e-4
    metrics=[Precision(), Recall()]  # Precision and Recall as metrics
)

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    checkpoint_cnn_filepath,       # Save the weights to this file
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only the best model (lowest validation loss)
    mode='min',                    # Minimize the validation loss
    save_weights_only=True,        # Save only the weights, not the full model
    verbose=1                      # Show a message when the model is saved
)

# Create the ModelCheckpoint callback for the LSTM model
checkpoint_lstm_callback = ModelCheckpoint(
    checkpoint_lstm_filepath,      # Save the weights to this file
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only the best model (lowest validation loss)
    mode='min',                    # Minimize the validation loss
    save_weights_only=True,        # Save only the weights, not the full model
    verbose=1                      # Show a message when the model is saved
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

from tensorflow.keras.callbacks import LearningRateScheduler

# Provided function to adjust the learning rate during training
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)  # Keep the learning rate constant for the first 10 epochs
    else:
        return float(lr * tf.math.exp(-0.01))  # Decay the learning rate after epoch 10

# Create the LearningRateScheduler callback using the scheduler function
lr_callback = LearningRateScheduler(scheduler,verbose=1)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,            # Training dataset
    epochs=40,                   # Train for 40 epochs
    validation_data=posters_valid_ds,  # Validation dataset
    callbacks=[checkpoint_cnn_callback, lr_callback],  # Callbacks: checkpoint and learning rate scheduler
    verbose=1                     # Print training progress
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4121 - precision: 0.2318 - recall: 0.2208
# Epoch 1: val_loss improved from inf to 0.34238, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 0.4074 - precision: 0.2368 - recall: 0.2208 - val_loss: 0.3424 - val_precision: 0.5383 - val_recall: 0.2278 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2568 - precision: 0.4946 - recall: 0.2169
# Epoch 2: val_loss improved from 0.34238 to 0.32178, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2567 - precision: 0.4948 - recall: 0.2170 - val_loss: 0.3218 - val_precision: 0.5645 - val_recall: 0.3226 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2449 - precision: 0.5296 - recall: 0.2281
# Epoch 3: val_loss improved from 0.32178 to 0.30817, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2448 - precision: 0.5302 - recall: 0.2287 - val_loss: 0.3082 - val_precision: 0.5763 - val_recall: 0.2410 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2400 - precision: 0.5473 - recall: 0.2486
# Epoch 4: val_loss improved from 0.30817 to 0.30428, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2400 - precision: 0.5473 - recall: 0.2486 - val_loss: 0.3043 - val_precision: 0.5544 - val_recall: 0.3755 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2358 - precision: 0.5560 - recall: 0.2695
# Epoch 5: val_loss improved from 0.30428 to 0.29861, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2358 - precision: 0.5560 - recall: 0.2692 - val_loss: 0.2986 - val_precision: 0.5668 - val_recall: 0.3491 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2339 - precision: 0.5608 - recall: 0.2678
# Epoch 6: val_loss improved from 0.29861 to 0.29477, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2339 - precision: 0.5608 - recall: 0.2676 - val_loss: 0.2948 - val_precision: 0.5695 - val_recall: 0.3412 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2311 - precision: 0.5759 - recall: 0.2717
# Epoch 7: val_loss did not improve from 0.29477
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2311 - precision: 0.5759 - recall: 0.2716 - val_loss: 0.2948 - val_precision: 0.5747 - val_recall: 0.3064 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2328 - precision: 0.5756 - recall: 0.2644
# Epoch 8: val_loss improved from 0.29477 to 0.28888, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2327 - precision: 0.5756 - recall: 0.2647 - val_loss: 0.2889 - val_precision: 0.5732 - val_recall: 0.3263 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2324 - precision: 0.5696 - recall: 0.2582
# Epoch 9: val_loss improved from 0.28888 to 0.28528, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2323 - precision: 0.5699 - recall: 0.2586 - val_loss: 0.2853 - val_precision: 0.5742 - val_recall: 0.3299 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2319 - precision: 0.5829 - recall: 0.2711
# Epoch 10: val_loss improved from 0.28528 to 0.27787, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2317 - precision: 0.5828 - recall: 0.2708 - val_loss: 0.2779 - val_precision: 0.5756 - val_recall: 0.3098 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 11/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2298 - precision: 0.5803 - recall: 0.2812
# Epoch 11: val_loss improved from 0.27787 to 0.27410, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2297 - precision: 0.5803 - recall: 0.2812 - val_loss: 0.2741 - val_precision: 0.5785 - val_recall: 0.3107 - learning_rate: 9.9005e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 12/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2282 - precision: 0.5778 - recall: 0.2692
# Epoch 12: val_loss did not improve from 0.27410
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2281 - precision: 0.5780 - recall: 0.2694 - val_loss: 0.2759 - val_precision: 0.5810 - val_recall: 0.3223 - learning_rate: 9.8020e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 13/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2280 - precision: 0.5830 - recall: 0.2783
# Epoch 13: val_loss improved from 0.27410 to 0.26574, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2280 - precision: 0.5832 - recall: 0.2784 - val_loss: 0.2657 - val_precision: 0.5807 - val_recall: 0.3177 - learning_rate: 9.7045e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 14/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2276 - precision: 0.5856 - recall: 0.2756
# Epoch 14: val_loss did not improve from 0.26574
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2276 - precision: 0.5858 - recall: 0.2756 - val_loss: 0.2697 - val_precision: 0.5723 - val_recall: 0.2840 - learning_rate: 9.6079e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 15/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2257 - precision: 0.5993 - recall: 0.2838
# Epoch 15: val_loss improved from 0.26574 to 0.25761, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2257 - precision: 0.5989 - recall: 0.2836 - val_loss: 0.2576 - val_precision: 0.6015 - val_recall: 0.2830 - learning_rate: 9.5123e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 16/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2267 - precision: 0.5918 - recall: 0.2708
# Epoch 16: val_loss did not improve from 0.25761
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2266 - precision: 0.5919 - recall: 0.2713 - val_loss: 0.2622 - val_precision: 0.5832 - val_recall: 0.2502 - learning_rate: 9.4176e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 17/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2264 - precision: 0.6024 - recall: 0.2633
# Epoch 17: val_loss did not improve from 0.25761
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2263 - precision: 0.6022 - recall: 0.2640 - val_loss: 0.2583 - val_precision: 0.5876 - val_recall: 0.2793 - learning_rate: 9.3239e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 18/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2234 - precision: 0.6058 - recall: 0.2698
# Epoch 18: val_loss did not improve from 0.25761
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2234 - precision: 0.6059 - recall: 0.2700 - val_loss: 0.2620 - val_precision: 0.5683 - val_recall: 0.2724 - learning_rate: 9.2312e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2249 - precision: 0.6054 - recall: 0.2765
# Epoch 19: val_loss did not improve from 0.25761
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2249 - precision: 0.6054 - recall: 0.2765 - val_loss: 0.2632 - val_precision: 0.5540 - val_recall: 0.2410 - learning_rate: 9.1393e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 20/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2214 - precision: 0.6137 - recall: 0.2830
# Epoch 20: val_loss improved from 0.25761 to 0.25474, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2215 - precision: 0.6134 - recall: 0.2828 - val_loss: 0.2547 - val_precision: 0.5509 - val_recall: 0.2360 - learning_rate: 9.0484e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 8.95834164111875e-05.
# Epoch 21/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2215 - precision: 0.6247 - recall: 0.2797
# Epoch 21: val_loss did not improve from 0.25474
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2215 - precision: 0.6246 - recall: 0.2796 - val_loss: 0.2560 - val_precision: 0.5742 - val_recall: 0.2840 - learning_rate: 8.9583e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 8.86920461198315e-05.
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2221 - precision: 0.6239 - recall: 0.2826
# Epoch 22: val_loss improved from 0.25474 to 0.24350, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2221 - precision: 0.6239 - recall: 0.2826 - val_loss: 0.2435 - val_precision: 0.5709 - val_recall: 0.2621 - learning_rate: 8.8692e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 8.78095452208072e-05.
# Epoch 23/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2208 - precision: 0.6284 - recall: 0.2746
# Epoch 23: val_loss did not improve from 0.24350
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2208 - precision: 0.6285 - recall: 0.2750 - val_loss: 0.2519 - val_precision: 0.5884 - val_recall: 0.2420 - learning_rate: 8.7810e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 8.69358264026232e-05.
# Epoch 24/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2207 - precision: 0.6359 - recall: 0.2751
# Epoch 24: val_loss did not improve from 0.24350
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2207 - precision: 0.6360 - recall: 0.2751 - val_loss: 0.2457 - val_precision: 0.5915 - val_recall: 0.2757 - learning_rate: 8.6936e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 8.607080235378817e-05.
# Epoch 25/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2201 - precision: 0.6401 - recall: 0.2802
# Epoch 25: val_loss did not improve from 0.24350
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2200 - precision: 0.6400 - recall: 0.2804 - val_loss: 0.2473 - val_precision: 0.5798 - val_recall: 0.2701 - learning_rate: 8.6071e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 8.521438576281071e-05.
# Epoch 26/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2182 - precision: 0.6494 - recall: 0.2824
# Epoch 26: val_loss did not improve from 0.24350
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2181 - precision: 0.6494 - recall: 0.2825 - val_loss: 0.2493 - val_precision: 0.5684 - val_recall: 0.2430 - learning_rate: 8.5214e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 8.436648931819946e-05.
# Epoch 27/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2172 - precision: 0.6365 - recall: 0.2766
# Epoch 27: val_loss did not improve from 0.24350
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2172 - precision: 0.6368 - recall: 0.2769 - val_loss: 0.2491 - val_precision: 0.5817 - val_recall: 0.2694 - learning_rate: 8.4366e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 8.352702570846304e-05.
# Epoch 28/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2165 - precision: 0.6525 - recall: 0.2927
# Epoch 28: val_loss improved from 0.24350 to 0.24021, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2165 - precision: 0.6525 - recall: 0.2925 - val_loss: 0.2402 - val_precision: 0.5691 - val_recall: 0.2545 - learning_rate: 8.3527e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 8.269591489806771e-05.
# Epoch 29/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2162 - precision: 0.6574 - recall: 0.2975
# Epoch 29: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2162 - precision: 0.6574 - recall: 0.2973 - val_loss: 0.2477 - val_precision: 0.5885 - val_recall: 0.2628 - learning_rate: 8.2696e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 8.187307685147971e-05.
# Epoch 30/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2147 - precision: 0.6521 - recall: 0.2931
# Epoch 30: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2147 - precision: 0.6521 - recall: 0.2928 - val_loss: 0.2423 - val_precision: 0.5784 - val_recall: 0.2635 - learning_rate: 8.1873e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 8.105842425720766e-05.
# Epoch 31/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2136 - precision: 0.6523 - recall: 0.2966
# Epoch 31: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2136 - precision: 0.6525 - recall: 0.2964 - val_loss: 0.2443 - val_precision: 0.5714 - val_recall: 0.2499 - learning_rate: 8.1058e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 8.025187707971781e-05.
# Epoch 32/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2124 - precision: 0.6519 - recall: 0.3008
# Epoch 32: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2124 - precision: 0.6520 - recall: 0.3007 - val_loss: 0.2464 - val_precision: 0.5800 - val_recall: 0.2612 - learning_rate: 8.0252e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 7.945335528347641e-05.
# Epoch 33/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2129 - precision: 0.6560 - recall: 0.2971
# Epoch 33: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2129 - precision: 0.6561 - recall: 0.2971 - val_loss: 0.2442 - val_precision: 0.5762 - val_recall: 0.2562 - learning_rate: 7.9453e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.86627788329497e-05.
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2111 - precision: 0.6613 - recall: 0.3032
# Epoch 34: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2111 - precision: 0.6614 - recall: 0.3032 - val_loss: 0.2438 - val_precision: 0.5797 - val_recall: 0.2489 - learning_rate: 7.8663e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 7.788007496856153e-05.
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2088 - precision: 0.6760 - recall: 0.3042
# Epoch 35: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2088 - precision: 0.6759 - recall: 0.3042 - val_loss: 0.2417 - val_precision: 0.6021 - val_recall: 0.2836 - learning_rate: 7.7880e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.710515637882054e-05.
# Epoch 36/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2102 - precision: 0.6685 - recall: 0.3055
# Epoch 36: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2102 - precision: 0.6686 - recall: 0.3054 - val_loss: 0.2480 - val_precision: 0.5825 - val_recall: 0.2579 - learning_rate: 7.7105e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.633795030415058e-05.
# Epoch 37/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2089 - precision: 0.6781 - recall: 0.3075
# Epoch 37: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2089 - precision: 0.6779 - recall: 0.3075 - val_loss: 0.2447 - val_precision: 0.5958 - val_recall: 0.2559 - learning_rate: 7.6338e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.55783767090179e-05.
# Epoch 38/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2073 - precision: 0.6710 - recall: 0.3117
# Epoch 38: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2073 - precision: 0.6710 - recall: 0.3117 - val_loss: 0.2481 - val_precision: 0.5950 - val_recall: 0.2588 - learning_rate: 7.5578e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.482636283384636e-05.
# Epoch 39/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2077 - precision: 0.6806 - recall: 0.3089
# Epoch 39: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2077 - precision: 0.6806 - recall: 0.3091 - val_loss: 0.2467 - val_precision: 0.5785 - val_recall: 0.2545 - learning_rate: 7.4826e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.40818286431022e-05.
# Epoch 40/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2060 - precision: 0.6831 - recall: 0.3216
# Epoch 40: val_loss did not improve from 0.24021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2060 - precision: 0.6830 - recall: 0.3215 - val_loss: 0.2442 - val_precision: 0.6064 - val_recall: 0.2638 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall


lstm_history = lstm_model.fit(
    overviews_train_ds,             # Training dataset for overviews
    epochs=20,                      # Train for 20 epochs
    validation_data=overviews_valid_ds,  # Validation dataset for overviews
    callbacks=[checkpoint_lstm_callback, lr_callback],  # Callbacks: checkpoint and learning rate scheduler
    verbose=1                        # Print training progress
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.6549 - precision_3: 0.1188 - recall_3: 0.4090
# Epoch 1: val_loss improved from inf to 0.33797, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - loss: 0.6541 - precision_3: 0.1190 - recall_3: 0.4084 - val_loss: 0.3380 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4509 - precision_3: 0.1843 - recall_3: 0.3022
# Epoch 2: val_loss improved from 0.33797 to 0.28538, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.4507 - precision_3: 0.1844 - recall_3: 0.3021 - val_loss: 0.2854 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4029 - precision_3: 0.2182 - recall_3: 0.2819
# Epoch 3: val_loss improved from 0.28538 to 0.26522, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.4027 - precision_3: 0.2183 - recall_3: 0.2819 - val_loss: 0.2652 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - loss: 0.3691 - precision_3: 0.2539 - recall_3: 0.2669
# Epoch 4: val_loss improved from 0.26522 to 0.25780, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 0.3690 - precision_3: 0.2540 - recall_3: 0.2669 - val_loss: 0.2578 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3507 - precision_3: 0.2883 - recall_3: 0.2586
# Epoch 5: val_loss improved from 0.25780 to 0.25059, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - loss: 0.3506 - precision_3: 0.2883 - recall_3: 0.2586 - val_loss: 0.2506 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - loss: 0.3317 - precision_3: 0.3183 - recall_3: 0.2569
# Epoch 6: val_loss improved from 0.25059 to 0.24804, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - loss: 0.3317 - precision_3: 0.3183 - recall_3: 0.2569 - val_loss: 0.2480 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3240 - precision_3: 0.3382 - recall_3: 0.2522
# Epoch 7: val_loss improved from 0.24804 to 0.24497, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.3239 - precision_3: 0.3383 - recall_3: 0.2521 - val_loss: 0.2450 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3125 - precision_3: 0.3611 - recall_3: 0.2409
# Epoch 8: val_loss improved from 0.24497 to 0.24315, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 0.3124 - precision_3: 0.3612 - recall_3: 0.2410 - val_loss: 0.2431 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 996ms/step - loss: 0.3063 - precision_3: 0.3736 - recall_3: 0.2330
# Epoch 9: val_loss improved from 0.24315 to 0.24249, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - loss: 0.3062 - precision_3: 0.3737 - recall_3: 0.2331 - val_loss: 0.2425 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2992 - precision_3: 0.3918 - recall_3: 0.2355
# Epoch 10: val_loss improved from 0.24249 to 0.24089, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.2992 - precision_3: 0.3918 - recall_3: 0.2355 - val_loss: 0.2409 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2926 - precision_3: 0.4032 - recall_3: 0.2368
# Epoch 11: val_loss improved from 0.24089 to 0.23964, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.2926 - precision_3: 0.4032 - recall_3: 0.2368 - val_loss: 0.2396 - val_precision_3: 0.5383 - val_recall_3: 0.2251 - learning_rate: 9.9005e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 981ms/step - loss: 0.2878 - precision_3: 0.4221 - recall_3: 0.2449
# Epoch 12: val_loss improved from 0.23964 to 0.23796, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - loss: 0.2877 - precision_3: 0.4221 - recall_3: 0.2449 - val_loss: 0.2380 - val_precision_3: 0.5408 - val_recall_3: 0.2255 - learning_rate: 9.8020e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - loss: 0.2804 - precision_3: 0.4452 - recall_3: 0.2513
# Epoch 13: val_loss improved from 0.23796 to 0.23536, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.2804 - precision_3: 0.4451 - recall_3: 0.2512 - val_loss: 0.2354 - val_precision_3: 0.5664 - val_recall_3: 0.2539 - learning_rate: 9.7045e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - loss: 0.2757 - precision_3: 0.4536 - recall_3: 0.2389
# Epoch 14: val_loss improved from 0.23536 to 0.23311, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - loss: 0.2757 - precision_3: 0.4537 - recall_3: 0.2389 - val_loss: 0.2331 - val_precision_3: 0.5790 - val_recall_3: 0.2750 - learning_rate: 9.6079e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - loss: 0.2686 - precision_3: 0.4771 - recall_3: 0.2516
# Epoch 15: val_loss improved from 0.23311 to 0.23120, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.2686 - precision_3: 0.4771 - recall_3: 0.2516 - val_loss: 0.2312 - val_precision_3: 0.5995 - val_recall_3: 0.2638 - learning_rate: 9.5123e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2633 - precision_3: 0.4943 - recall_3: 0.2574
# Epoch 16: val_loss improved from 0.23120 to 0.22853, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - loss: 0.2633 - precision_3: 0.4943 - recall_3: 0.2574 - val_loss: 0.2285 - val_precision_3: 0.6146 - val_recall_3: 0.2473 - learning_rate: 9.4176e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - loss: 0.2582 - precision_3: 0.4970 - recall_3: 0.2769
# Epoch 17: val_loss improved from 0.22853 to 0.22841, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 0.2582 - precision_3: 0.4970 - recall_3: 0.2769 - val_loss: 0.2284 - val_precision_3: 0.5887 - val_recall_3: 0.2972 - learning_rate: 9.3239e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2545 - precision_3: 0.5185 - recall_3: 0.2851
# Epoch 18: val_loss improved from 0.22841 to 0.22612, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.2545 - precision_3: 0.5184 - recall_3: 0.2850 - val_loss: 0.2261 - val_precision_3: 0.6147 - val_recall_3: 0.2605 - learning_rate: 9.2312e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2533 - precision_3: 0.5135 - recall_3: 0.2781
# Epoch 19: val_loss improved from 0.22612 to 0.22570, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - loss: 0.2533 - precision_3: 0.5136 - recall_3: 0.2781 - val_loss: 0.2257 - val_precision_3: 0.6120 - val_recall_3: 0.2764 - learning_rate: 9.1393e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - loss: 0.2512 - precision_3: 0.5146 - recall_3: 0.2762
# Epoch 20: val_loss improved from 0.22570 to 0.22527, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.2511 - precision_3: 0.5147 - recall_3: 0.2763 - val_loss: 0.2253 - val_precision_3: 0.6099 - val_recall_3: 0.2760 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

# Plot for LSTM model loss

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('cnn Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(1)
plt.show()

# Plot for LSTM model accuracy (assuming accuracy was monitored)
# Plotting the Accuracy
# Plot Training and Validation Precision
plt.figure(figsize=(12, 6))

plt.plot(cnn_history.history['precision'], label='Training Precision')
plt.plot(cnn_history.history['val_precision'], label='Validation Precision', linestyle='--')
plt.title('CNN Model Precision Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot for LSTM model accuracy (assuming accuracy was monitored)
# Plotting the Accuracy
# Plot Training and Validation Precision
plt.figure(figsize=(12, 6))

plt.plot(lstm_history.history['precision'], label='Training Precision')
plt.plot(lstm_history.history['val_precision'], label='Validation Precision', linestyle='--')
plt.title('lstm Model Precision Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c
import matplotlib.pyplot as plt
import numpy as np

# Load the best weights for both models
cnn_model.load_weights(checkpoint_cnn_filepath)
lstm_model.load_weights(checkpoint_lstm_filepath)

# Choose a few films (replace with actual indices from your dataset)
example_indices = [0, 1, 2]  # Example indices, replace with your desired film indices

# Function to get top 3 genres
def get_top_3_genres(predictions, genre_names):
    top_3_indices = np.argsort(predictions)[-3:][::-1]  # Get indices of top 3
    top_3_genres = [genre_names[i] for i in top_3_indices]
    return top_3_genres

# Assuming you have 'genre_names' available
genre_names = list(dataset.columns[3:])  # Assuming genres start from column index 3

for i in example_indices:
    # Assuming 'posters_train_ds' and 'overviews_train_ds' are tf.data.Datasets
    # Accessing elements from a tf.data.Dataset requires iteration:

    # Get the poster and overview for the current index
    for j, (image_batch, label_batch) in enumerate(posters_train_ds):
      if j == i:
        poster = image_batch[0] #Assuming one poster per batch for simplicity
        break

    for j, (overview_batch, label_batch) in enumerate(overviews_train_ds):
      if j == i:
        overview = overview_batch[0] # Assuming one overview per batch
        break

    # CNN prediction
    cnn_predictions = cnn_model.predict(np.expand_dims(poster, axis=0))
    top_3_cnn = get_top_3_genres(cnn_predictions[0], genre_names)


    # LSTM prediction
    lstm_predictions = lstm_model.predict(np.expand_dims(overview, axis=0))
    top_3_lstm = get_top_3_genres(lstm_predictions[0], genre_names)


    # Ground truth genres (replace with actual ground truth retrieval method)
    ground_truth = list(dataset.iloc[i][3:])
    ground_truth = [genre_names[idx] for idx, val in enumerate(ground_truth) if val == 1]

    # Plot the poster
    plt.imshow(poster)
    plt.title(f"Film {i}")
    plt.axis('off')
    plt.show()

    # Print the overview (handle potential errors gracefully)
    try:
        print("Overview:", dataset['Overview'].iloc[i][:200] + "...")
    except Exception as e:
        print(f"Error printing overview for film {i}: {e}")


    print("\nGround Truth Genres:", ground_truth)
    print("CNN's Top 3 Predicted Genres:", top_3_cnn)
    print("LSTM's Top 3 Predicted Genres:", top_3_lstm)
    print("-" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Overview: Follows hard-to-please Aurora looking for love, and her daughter's family problems....
#
# Ground Truth Genres: ['Comedy', 'Drama']
# CNN's Top 3 Predicted Genres: ['Family', 'Adventure', 'Crime']
# LSTM's Top 3 Predicted Genres: ['Adventure', 'Family', 'Animation']
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# Overview: A Pittsburgh woman with two jobs as a welder and an exotic dancer wants to get into ballet school....
#
# Ground Truth Genres: ['Drama', 'Music', 'Romance']
# CNN's Top 3 Predicted Genres: ['Family', 'Adventure', 'Documentary']
# LSTM's Top 3 Predicted Genres: ['Family', 'Crime', 'Documentary']
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# Overview: A snobbish investor and a wily street con artist find their positions reversed as part of a bet by two callous millionaires....
#
# Ground Truth Genres: ['Comedy']
# CNN's Top 3 Predicted Genres: ['Family', 'Crime', 'Sci-Fi']
# LSTM's Top 3 Predicted Genres: ['Family', 'Crime', 'Adventure']
# --------------------------------------------------
